# %% [markdown]
# ## Práctica

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/aitor/Downloads/Matriculaciones.csv",
           sep=";", encoding="latin1", decimal=",")
df
# Out:
#      SERIES   PRODUCCIÓN DE TURISMOS EXPORTACIONES DE TURISMOS  \
# 0    196001                        -                         -
# 1    196002                        -                         -
# 2    196003                        -                         -
# 3    196004                        -                         -
# 4    196005                        -                         -
# ..      ...                      ...                       ...
# 737  202106  146311,0000000000000000   127058,0000000000000000
# 738  202107  105838,0000000000000000    89616,0000000000000000
# 739  202108   52399,0000000000000000    50770,0000000000000000
# 740  202109  141930,0000000000000000   135302,0000000000000000
# 741  202110  129672,0000000000000000   111829,0000000000000000
#
#      MATRICULACIONES DE TURISMOS.  TOTAL
# 0                                 3360.0
# 1                                 4385.0
# 2                                 4055.0
# 3                                 5380.0
# 4                                 6309.0
# ..                                   ...
# 737                             103467.0
# 738                              92171.0
# 739                              54561.0
# 740                              67792.0
# 741                              67899.0
#
# [742 rows x 4 columns]

# %%
df["SERIES"] = pd.to_datetime(df["SERIES"])
df
# Out:
#                            SERIES   PRODUCCIÓN DE TURISMOS  \
# 0   1970-01-01 00:00:00.000196001                        -
# 1   1970-01-01 00:00:00.000196002                        -
# 2   1970-01-01 00:00:00.000196003                        -
# 3   1970-01-01 00:00:00.000196004                        -
# 4   1970-01-01 00:00:00.000196005                        -
# ..                            ...                      ...
# 737 1970-01-01 00:00:00.000202106  146311,0000000000000000
# 738 1970-01-01 00:00:00.000202107  105838,0000000000000000
# 739 1970-01-01 00:00:00.000202108   52399,0000000000000000
# 740 1970-01-01 00:00:00.000202109  141930,0000000000000000
# 741 1970-01-01 00:00:00.000202110  129672,0000000000000000
#
#     EXPORTACIONES DE TURISMOS  MATRICULACIONES DE TURISMOS.  TOTAL
# 0                           -                               3360.0
# 1                           -                               4385.0
# 2                           -                               4055.0
# 3                           -                               5380.0
# 4                           -                               6309.0
# ..                        ...                                  ...
# 737   127058,0000000000000000                             103467.0
# 738    89616,0000000000000000                              92171.0
# 739    50770,0000000000000000                              54561.0
# 740   135302,0000000000000000                              67792.0
# 741   111829,0000000000000000                              67899.0
#
# [742 rows x 4 columns]

# %%
df.index=pd.date_range(end="2021-11", start="1960-01", freq="M")

# %%
df = df.drop("SERIES", axis=1)

# %%
df.columns =["Producción", "Exportaciones", "Matriculaciones"]

# %%
df_m = df.resample("m").last().drop(["Producción", "Exportaciones"], axis=1)

# %%
df = df.to_period("m")

# %%
df = df.drop(["Producción", "Exportaciones"], axis=1)

# %%
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(11, 4)})
ax = df.plot( linestyle='-')
ax.set_ylabel('Matriculaciones');

# %%
sns.set(rc={'figure.figsize':(11, 4)})
ax = df["1990":].plot( linestyle='-')
ax.set_ylabel('Matriculaciones');

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 742 entries, 1960-01 to 2021-10
# Freq: M
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Matriculaciones  742 non-null    float64
# dtypes: float64(1)
# memory usage: 27.8 KB

# %%
df_m
# Out:
#             Matriculaciones
# 1960-01-31           3360.0
# 1960-02-29           4385.0
# 1960-03-31           4055.0
# 1960-04-30           5380.0
# 1960-05-31           6309.0
# ...                     ...
# 2021-06-30         103467.0
# 2021-07-31          92171.0
# 2021-08-31          54561.0
# 2021-09-30          67792.0
# 2021-10-31          67899.0
#
# [742 rows x 1 columns]

# %%
from statsmodels.tsa.seasonal import STL

stl = STL(df_m)
res = stl.fit()
fig = res.plot()

# %%
df = df["2000":]

# %%
sns.set(rc={'figure.figsize':(11, 4)})
ax = df.plot( linestyle='-')
ax.set_ylabel('Matriculaciones');
