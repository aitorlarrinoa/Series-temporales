# %% [markdown]
# # Series Temporales HW 03: BMW vs Volkswagen

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import statsmodels.formula.api as smf
import statsmodels.api as sm
import datetime
import seaborn as sns
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.api import VAR
from statsmodels.tsa.base.datetools import dates_from_str

# %%
bmw = yf.Ticker("BMW.DE")
volks = yf.Ticker("VOW.DE")
start = datetime.datetime(2009,1,1) 
end = datetime.datetime(2020,10,31)

# %%
bmw = bmw.history(start=start, end=end)
volks = volks.history(start=start, end=end)

# %%
bmw
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2009-01-02  13.823102  14.366562  13.823102  14.283445  1830895        0.0
# 2009-01-05  14.424109  14.424109  13.887041  13.973355  2226528        0.0
# 2009-01-06  14.002126  14.161967  13.855072  13.922205  2756874        0.0
# 2009-01-07  13.826300  14.203526  13.720804  14.091638  2313297        0.0
# 2009-01-08  14.005326  14.222711  13.663265  14.002129  2468677        0.0
# ...               ...        ...        ...        ...      ...        ...
# 2020-10-26  60.019884  61.222957  59.943497  60.354069  1118941        0.0
# 2020-10-27  60.373163  60.430453  58.568557  58.692684  1839591        0.0
# 2020-10-28  57.031301  57.250909  54.663352  55.436756  3729376        0.0
# 2020-10-29  55.245791  56.296090  54.978443  55.694557  1788596        0.0
# 2020-10-30  54.806574  56.210154  54.777927  56.028740  1564460        0.0
#
#             Stock Splits
# Date
# 2009-01-02             0
# 2009-01-05             0
# 2009-01-06             0
# 2009-01-07             0
# 2009-01-08             0
# ...                  ...
# 2020-10-26             0
# 2020-10-27             0
# 2020-10-28             0
# 2020-10-29             0
# 2020-10-30             0
#
# [3003 rows x 7 columns]

# %%
bmw = bmw.drop(['Low','High','Open','Volume','Dividends', 'Stock Splits'], axis=1)
volks = volks.drop(['Low','High','Open','Volume','Dividends', 'Stock Splits'], axis=1)

# %%
bmw = bmw.resample('m').last().dropna().astype('float64').to_period('M')
bmw
# Out:
#              Close
# Date
# 2009-01  11.898609
# 2009-02  12.627488
# 2009-03  13.931795
# 2009-04  16.783371
# 2009-05  16.435892
# ...            ...
# 2020-06  54.252777
# 2020-07  52.228565
# 2020-08  57.432327
# 2020-09  59.189190
# 2020-10  56.028740
#
# [142 rows x 1 columns]

# %%
volks = volks.resample('m').last().dropna().astype('float64').to_period('M')
volks
# Out:
#               Close
# Date
# 2009-01  192.005585
# 2009-02  144.706558
# 2009-03  178.035263
# 2009-04  185.695969
# 2009-05  165.715973
# ...             ...
# 2020-06  136.308868
# 2020-07  126.226013
# 2020-08  142.872238
# 2020-09  141.921021
# 2020-10  131.306442
#
# [142 rows x 1 columns]

# %%
data = bmw.merge(volks, on= 'Date')
data = data.rename(columns={'Date':'Date', 'Close_x': 'BMW', 'Close_y': 'Volkswagen'})

# %%
data
# Out:
#                BMW  Volkswagen
# Date
# 2009-01  11.898609  192.005585
# 2009-02  12.627488  144.706558
# 2009-03  13.931795  178.035263
# 2009-04  16.783371  185.695969
# 2009-05  16.435892  165.715973
# ...            ...         ...
# 2020-06  54.252777  136.308868
# 2020-07  52.228565  126.226013
# 2020-08  57.432327  142.872238
# 2020-09  59.189190  141.921021
# 2020-10  56.028740  131.306442
#
# [142 rows x 2 columns]

# %%
price_bmw = data.iloc[-1, 0]
price_volks = data.iloc[-1, 1]

# %%
returns_df = np.log(data).diff().dropna()
returns_df
# Out:
#               BMW  Volkswagen
# Date
# 2009-02  0.059455   -0.282817
# 2009-03  0.098298    0.207274
# 2009-04  0.186215    0.042129
# 2009-05 -0.020921   -0.113835
# 2009-06  0.055341    0.121788
# ...           ...         ...
# 2020-06  0.077172    0.006300
# 2020-07 -0.038025   -0.076849
# 2020-08  0.094978    0.123877
# 2020-09  0.030132   -0.006680
# 2020-10 -0.054874   -0.077737
#
# [141 rows x 2 columns]

# %% [markdown]
# ### Test de Granger
# H0 -> La serie de la segunda columna **NO** es causa de la primera con un cierto retraso.
#
# H1 -> La serie de la segunda columna **SÍ** es causa de la primera con un cierto retraso.
#
#
#
# P-Value > 0.05. -> No hay causalidad
#
# P-Value < 0.05. -> Hay causalidad

# %%
gc_res = grangercausalitytests(returns_df[['BMW','Volkswagen']], 12)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2485  , p=0.2658  , df_denom=137, df_num=1
# ssr based chi2 test:   chi2=1.2759  , p=0.2587  , df=1
# likelihood ratio test: chi2=1.2701  , p=0.2598  , df=1
# parameter F test:         F=1.2485  , p=0.2658  , df_denom=137, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.8676  , p=0.1585  , df_denom=134, df_num=2
# ssr based chi2 test:   chi2=3.8746  , p=0.1441  , df=2
# likelihood ratio test: chi2=3.8216  , p=0.1480  , df=2
# parameter F test:         F=1.8676  , p=0.1585  , df_denom=134, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3699  , p=0.2549  , df_denom=131, df_num=3
# ssr based chi2 test:   chi2=4.3293  , p=0.2280  , df=3
# likelihood ratio test: chi2=4.2627  , p=0.2345  , df=3
# parameter F test:         F=1.3699  , p=0.2549  , df_denom=131, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1026  , p=0.3583  , df_denom=128, df_num=4
# ssr based chi2 test:   chi2=4.7206  , p=0.3172  , df=4
# likelihood ratio test: chi2=4.6411  , p=0.3261  , df=4
# parameter F test:         F=1.1026  , p=0.3583  , df_denom=128, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8754  , p=0.4998  , df_denom=125, df_num=5
# ssr based chi2 test:   chi2=4.7619  , p=0.4456  , df=5
# likelihood ratio test: chi2=4.6805  , p=0.4561  , df=5
# parameter F test:         F=0.8754  , p=0.4998  , df_denom=125, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9477  , p=0.4638  , df_denom=122, df_num=6
# ssr based chi2 test:   chi2=6.2918  , p=0.3913  , df=6
# likelihood ratio test: chi2=6.1496  , p=0.4066  , df=6
# parameter F test:         F=0.9477  , p=0.4638  , df_denom=122, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2105  , p=0.3023  , df_denom=119, df_num=7
# ssr based chi2 test:   chi2=9.5417  , p=0.2161  , df=7
# likelihood ratio test: chi2=9.2173  , p=0.2374  , df=7
# parameter F test:         F=1.2105  , p=0.3023  , df_denom=119, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.4158  , p=0.1971  , df_denom=116, df_num=8
# ssr based chi2 test:   chi2=12.9862 , p=0.1123  , df=8
# likelihood ratio test: chi2=12.3907 , p=0.1346  , df=8
# parameter F test:         F=1.4158  , p=0.1971  , df_denom=116, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.7131  , p=0.0939  , df_denom=113, df_num=9
# ssr based chi2 test:   chi2=18.0108 , p=0.0350  , df=9
# likelihood ratio test: chi2=16.8835 , p=0.0506  , df=9
# parameter F test:         F=1.7131  , p=0.0939  , df_denom=113, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.3027  , p=0.0170  , df_denom=110, df_num=10
# ssr based chi2 test:   chi2=27.4237 , p=0.0022  , df=10
# likelihood ratio test: chi2=24.8999 , p=0.0055  , df=10
# parameter F test:         F=2.3027  , p=0.0170  , df_denom=110, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.1050  , p=0.0258  , df_denom=107, df_num=11
# ssr based chi2 test:   chi2=28.1318 , p=0.0031  , df=11
# likelihood ratio test: chi2=25.4663 , p=0.0078  , df=11
# parameter F test:         F=2.1050  , p=0.0258  , df_denom=107, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.8013  , p=0.0572  , df_denom=104, df_num=12
# ssr based chi2 test:   chi2=26.8113 , p=0.0082  , df=12
# likelihood ratio test: chi2=24.3595 , p=0.0182  , df=12
# parameter F test:         F=1.8013  , p=0.0572  , df_denom=104, df_num=12

# %%
gc_res = grangercausalitytests(returns_df[['Volkswagen', 'BMW']], 12)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2544  , p=0.6148  , df_denom=137, df_num=1
# ssr based chi2 test:   chi2=0.2600  , p=0.6101  , df=1
# likelihood ratio test: chi2=0.2598  , p=0.6103  , df=1
# parameter F test:         F=0.2544  , p=0.6148  , df_denom=137, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7183  , p=0.4895  , df_denom=134, df_num=2
# ssr based chi2 test:   chi2=1.4902  , p=0.4747  , df=2
# likelihood ratio test: chi2=1.4822  , p=0.4766  , df=2
# parameter F test:         F=0.7183  , p=0.4895  , df_denom=134, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1608  , p=0.3273  , df_denom=131, df_num=3
# ssr based chi2 test:   chi2=3.6685  , p=0.2996  , df=3
# likelihood ratio test: chi2=3.6206  , p=0.3055  , df=3
# parameter F test:         F=1.1608  , p=0.3273  , df_denom=131, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.1260  , p=0.0813  , df_denom=128, df_num=4
# ssr based chi2 test:   chi2=9.1021  , p=0.0586  , df=4
# likelihood ratio test: chi2=8.8125  , p=0.0660  , df=4
# parameter F test:         F=2.1260  , p=0.0813  , df_denom=128, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.3604  , p=0.0438  , df_denom=125, df_num=5
# ssr based chi2 test:   chi2=12.8407 , p=0.0249  , df=5
# likelihood ratio test: chi2=12.2701 , p=0.0313  , df=5
# parameter F test:         F=2.3604  , p=0.0438  , df_denom=125, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.0248  , p=0.0673  , df_denom=122, df_num=6
# ssr based chi2 test:   chi2=13.4436 , p=0.0365  , df=6
# likelihood ratio test: chi2=12.8155 , p=0.0461  , df=6
# parameter F test:         F=2.0248  , p=0.0673  , df_denom=122, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2621  , p=0.2750  , df_denom=119, df_num=7
# ssr based chi2 test:   chi2=9.9481  , p=0.1915  , df=7
# likelihood ratio test: chi2=9.5961  , p=0.2126  , df=7
# parameter F test:         F=1.2621  , p=0.2750  , df_denom=119, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6821  , p=0.1099  , df_denom=116, df_num=8
# ssr based chi2 test:   chi2=15.4289 , p=0.0513  , df=8
# likelihood ratio test: chi2=14.5977 , p=0.0675  , df=8
# parameter F test:         F=1.6821  , p=0.1099  , df_denom=116, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5107  , p=0.1525  , df_denom=113, df_num=9
# ssr based chi2 test:   chi2=15.8821 , p=0.0694  , df=9
# likelihood ratio test: chi2=14.9970 , p=0.0910  , df=9
# parameter F test:         F=1.5107  , p=0.1525  , df_denom=113, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1849  , p=0.3088  , df_denom=110, df_num=10
# ssr based chi2 test:   chi2=14.1115 , p=0.1680  , df=10
# likelihood ratio test: chi2=13.4020 , p=0.2021  , df=10
# parameter F test:         F=1.1849  , p=0.3088  , df_denom=110, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.0444  , p=0.4134  , df_denom=107, df_num=11
# ssr based chi2 test:   chi2=13.9579 , p=0.2353  , df=11
# likelihood ratio test: chi2=13.2582 , p=0.2768  , df=11
# parameter F test:         F=1.0444  , p=0.4134  , df_denom=107, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.7705  , p=0.6792  , df_denom=104, df_num=12
# ssr based chi2 test:   chi2=11.4683 , p=0.4893  , df=12
# likelihood ratio test: chi2=10.9869 , p=0.5300  , df=12
# parameter F test:         F=0.7705  , p=0.6792  , df_denom=104, df_num=12

# %% [markdown]
# ## Selección Automática del VAR

# %%
model = VAR(returns_df)

# %%
model.select_order(15)

# %%
results = model.fit(maxlags=15, ic='aic')
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 24, Nov, 2021
# Time:                     20:17:08
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -9.78183
# Nobs:                     140.000    HQIC:                  -9.85667
# Log likelihood:           302.251    FPE:                4.97803e-05
# AIC:                     -9.90790    Det(Omega_mle):     4.77135e-05
# --------------------------------------------------------------------
# Results for equation BMW
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.009729         0.007009            1.388           0.165
# L1.BMW                0.063438         0.105383            0.602           0.547
# L1.Volkswagen        -0.086737         0.077626           -1.117           0.264
# ================================================================================
#
# Results for equation Volkswagen
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.000198         0.009330            0.021           0.983
# L1.BMW               -0.070755         0.140271           -0.504           0.614
# L1.Volkswagen         0.037482         0.103325            0.363           0.717
# ================================================================================
#
# Correlation matrix of residuals
#                    BMW  Volkswagen
# BMW           1.000000    0.623386
# Volkswagen    0.623386    1.000000

# %%
sns.set(rc={'figure.figsize':(20, 10)})
ax = data.plot(marker='o', linestyle='-')
ax.set_ylabel('Precio Acciones')
ax.set_xlabel('Mes/Año')
ax.set_title('Evolución Mensual del Precio de las Acciones de BMW y VW')
# Out:
# Text(0.5, 1.0, 'Evolución Mensual del Precio de las Acciones de BMW y VW')

# %%
sns.set(rc={'figure.figsize':(20, 10)})
ax = returns_df.plot(marker='o', linestyle='-')
ax.set_ylabel('Precio Acciones')
ax.set_xlabel('Mes/Año')
ax.set_title('Evolución Mensual del Precio de las Acciones de BMW y VW')
# Out:
# Text(0.5, 1.0, 'Evolución Mensual del Precio de las Acciones de BMW y VW')

# %% [markdown]
# ## Predicción

# %%
lag_order = results.k_ar
predictions_VAR = results.forecast(returns_df.values[-lag_order:], 12)
predictions_VAR
# Out:
# array([[ 0.01299013,  0.00116648],
#        [ 0.01045144, -0.00067776],
#        [ 0.01045036, -0.00056726],
#        [ 0.01044071, -0.00056305],
#        [ 0.01043973, -0.0005622 ],
#        [ 0.01043959, -0.0005621 ],
#        [ 0.01043958, -0.00056209],
#        [ 0.01043957, -0.00056209],
#        [ 0.01043957, -0.00056209],
#        [ 0.01043957, -0.00056209],
#        [ 0.01043957, -0.00056209],
#        [ 0.01043957, -0.00056209]])

# %%
VAR_bmw = (np.exp(np.cumsum(predictions_VAR[:,0]))*price_bmw)[-1]
VAR_volks = (np.exp(np.cumsum(predictions_VAR[:,1]))*price_volks)[-1]
print(VAR_bmw, VAR_volks)
# Out:
# 63.67004350666539 130.6334629446502

# %%
bmw_comparison = yf.Ticker("BMW.DE")
volks_comparison = yf.Ticker("VOW.DE")
start = datetime.datetime(2009,1,1) 
end = datetime.datetime(2021,10,31)

# %%
bmw_comparison = bmw_comparison.history(start=start, end=end)
volks_comparison = volks_comparison.history(start=start, end=end)

# %%
bmw = bmw_comparison.drop(['Low','High','Open','Volume','Dividends', 'Stock Splits'], axis=1)
volks = volks_comparison.drop(['Low','High','Open','Volume','Dividends', 'Stock Splits'], axis=1)

# %%
bmw = bmw.resample('m').last().dropna().astype('float64').to_period('M')
volks = volks.resample('m').last().dropna().astype('float64').to_period('M')

# %%
data = bmw.merge(volks, on= 'Date')
data = data.rename(columns={'Date':'Date', 'Close_x': 'BMW', 'Close_y': 'Volkswagen'})
data
# Out:
#                BMW  Volkswagen
# Date
# 2009-01  11.898610  192.005569
# 2009-02  12.627488  144.706543
# 2009-03  13.931798  178.035263
# 2009-04  16.783369  185.695969
# 2009-05  16.435896  165.715973
# ...            ...         ...
# 2021-06  89.309998  272.048065
# 2021-07  83.879997  280.000000
# 2021-08  80.370003  283.200012
# 2021-09  82.760002  268.000000
# 2021-10  87.239998  280.799988
#
# [154 rows x 2 columns]

# %% [markdown]
# ### Plot de los forecast

# %%
results.plot_forecast(12);

# %% [markdown]
# ### Función de Respuesta al Impulso

# %%
irf = results.irf(12)

# %%
irf.plot(orth=False);

# %%
irf.plot_cum_effects(orth=False);

# %%
fevd = results.fevd(12)
fevd.summary()
# Out:
# FEVD for BMW
#            BMW  Volkswagen
# 0     1.000000    0.000000
# 1     0.991917    0.008083
# 2     0.991835    0.008165
# 3     0.991834    0.008166
# 4     0.991834    0.008166
# 5     0.991834    0.008166
# 6     0.991834    0.008166
# 7     0.991834    0.008166
# 8     0.991834    0.008166
# 9     0.991834    0.008166
# 10    0.991834    0.008166
# 11    0.991834    0.008166
#
# FEVD for Volkswagen
#            BMW  Volkswagen
# 0     0.388610    0.611390
# 1     0.388818    0.611182
# 2     0.388805    0.611195
# 3     0.388805    0.611195
# 4     0.388805    0.611195
# 5     0.388805    0.611195
# 6     0.388805    0.611195
# 7     0.388805    0.611195
# 8     0.388805    0.611195
# 9     0.388805    0.611195
# 10    0.388805    0.611195
# 11    0.388805    0.611195

# %%
results.fevd(20).plot();

# %% [markdown]
# ### Causalidad Granger

# %%
results.test_causality('Volkswagen', 'BMW', kind='f').summary() # BMW explica el precio de Volkswagen
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results.test_causality('BMW', 'Volkswagen', kind='f').summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ### Normalidad

# %%
results.test_normality().summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# # Volatilidad: Modelos GARCH

# %%
bmw = yf.Ticker("BMW.DE")
volks = yf.Ticker("VOW.DE")
start = datetime.datetime(1996,11,8) 
end = datetime.datetime(2020,10,31)

# %%
bmw = bmw.history(start=start, end=end)

# %%
bmw
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 1996-11-08  10.063326  10.063326  10.041774  10.041774   767000        0.0
# 1996-11-11  10.052275  10.057802   9.992592  10.014696   260000        0.0
# 1996-11-12  10.036246  10.128535   9.998115  10.090405  1066000        0.0
# 1996-11-13  10.137377  10.137377  10.052273  10.074377   793000        0.0
# 1996-11-14  10.060564  10.106984  10.020222  10.106984   351000        0.0
# ...               ...        ...        ...        ...      ...        ...
# 2020-10-26  60.019884  61.222957  59.943497  60.354069  1118941        0.0
# 2020-10-27  60.373167  60.430457  58.568561  58.692688  1839591        0.0
# 2020-10-28  57.031301  57.250909  54.663352  55.436756  3729376        0.0
# 2020-10-29  55.245791  56.296090  54.978443  55.694557  1788596        0.0
# 2020-10-30  54.806574  56.210154  54.777927  56.028740  1564460        0.0
#
#             Stock Splits
# Date
# 1996-11-08             0
# 1996-11-11             0
# 1996-11-12             0
# 1996-11-13             0
# 1996-11-14             0
# ...                  ...
# 2020-10-26             0
# 2020-10-27             0
# 2020-10-28             0
# 2020-10-29             0
# 2020-10-30             0
#
# [6150 rows x 7 columns]

# %%
bmw = bmw.drop(['Low','High','Open','Volume','Dividends', 'Stock Splits'], axis=1)

# %%
bmw
# Out:
#                 Close
# Date
# 1996-11-08  10.041774
# 1996-11-11  10.014696
# 1996-11-12  10.090405
# 1996-11-13  10.074377
# 1996-11-14  10.106984
# ...               ...
# 2020-10-26  60.354069
# 2020-10-27  58.692688
# 2020-10-28  55.436756
# 2020-10-29  55.694557
# 2020-10-30  56.028740
#
# [6150 rows x 1 columns]

# %%
price_bmw2 = bmw.iloc[-1, 0]
price_bmw2
# Out:
# 56.02873992919922

# %%
bmw_returns = bmw.rename(columns={'Date':'Date', 'Close':'Price'})
bmw_returns
# Out:
#                 Price
# Date
# 1996-11-08  10.041774
# 1996-11-11  10.014696
# 1996-11-12  10.090405
# 1996-11-13  10.074377
# 1996-11-14  10.106984
# ...               ...
# 2020-10-26  60.354069
# 2020-10-27  58.692688
# 2020-10-28  55.436756
# 2020-10-29  55.694557
# 2020-10-30  56.028740
#
# [6150 rows x 1 columns]

# %%
sns.set(rc={'figure.figsize':(11, 4)})
# Plot stock prices
ax = bmw_returns.Price.plot( linestyle='-')
ax.set_ylabel('Price');

# %% [markdown]
# ## Calculate Daily Logarithmic Return and Squared

# %%
bmw_returns['log_ret'] =np.log(bmw_returns.Price).diff()
bmw_returns.tail()
# Out:
#                 Price   log_ret
# Date
# 2020-10-26  60.354069 -0.011326
# 2020-10-27  58.692688 -0.027913
# 2020-10-28  55.436756 -0.057072
# 2020-10-29  55.694557  0.004640
# 2020-10-30  56.028740  0.005982

# %%
bmw_returns['Squared'] =bmw_returns['log_ret']**2
bmw_returns.tail()
# Out:
#                 Price   log_ret   Squared
# Date
# 2020-10-26  60.354069 -0.011326  0.000128
# 2020-10-27  58.692688 -0.027913  0.000779
# 2020-10-28  55.436756 -0.057072  0.003257
# 2020-10-29  55.694557  0.004640  0.000022
# 2020-10-30  56.028740  0.005982  0.000036

# %% [markdown]
# # Plot return squared

# %%
fig = plt.figure(figsize=(10,10))
plt.subplot(311)
ax=bmw_returns.Price.plot( linestyle='-')
ax.set_ylabel('BMW')
ax.set_xlabel('')
ax.set_title('BMW', y=1, fontsize = 16)
plt.subplot(312)
ax=bmw_returns.log_ret.plot( linestyle='-')
ax.set_ylabel('Rentabilidad')
ax.set_xlabel('')
ax.set_title('Rentabilidad', y=0.8, x=0.6,fontsize = 16)
plt.subplot(313)
ax=bmw_returns.Squared.plot( linestyle='-')
ax.set_ylabel('BMW')
ax.set_xlabel('')
ax.set_title('Volatilidad', y=0.8, fontsize = 16)
# Out:
# Text(0.5, 0.8, 'Volatilidad')

# %% [markdown]
# ## Testing mean

# %%
from scipy import stats
alpha=0.05
t, p =stats.ttest_1samp(bmw_returns['log_ret'].dropna(),0.0)
print ('Estadítico t:',t)
print ('p-value:',p)

if  p < alpha:
    print (f'Con {alpha} de significación: Rechazamos la hipotesis de media cero.')
else:
    print (f'Con {alpha} de significación: No podemos rechazar la hipotesis de media cero.')
# Out:
# Estadítico t: 1.0061952008785355
# p-value: 0.3143612793565702
# Con 0.05 de significación: No podemos rechazar la hipotesis de media cero.

# %% [markdown]
# ## ACF y PACF ## Ljung-Box Test

# %%
# Autocorrelation Fuction Original Time Series
from sktime.utils.plotting import plot_correlations

# %%
bmw_vol=bmw_returns['Squared'].astype('float64').to_period('D').sort_index().dropna()
bmw_vol.tail()
# Out:
# Date
# 2020-10-26    0.000128
# 2020-10-27    0.000779
# 2020-10-28    0.003257
# 2020-10-29    0.000022
# 2020-10-30    0.000036
# Freq: D, Name: Squared, dtype: float64

# %%
# Plot Autocorrelation
plot_correlations(bmw_vol)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<AxesSubplot:ylabel='Squared'>,
#         <AxesSubplot:title={'center':'Autocorrelation'}>,
#         <AxesSubplot:title={'center':'Partial Autocorrelation'}>],
#        dtype=object))

# %%
# import function test Ljung_Box
import statsmodels.api as sm
test_Ljung_Box=sm.stats.acorr_ljungbox

# %%
#
# testing Ljung-Box
# pvalue < alpha -> No Ruido Blanco
test_Ljung_Box(bmw_vol, lags=[10,20,30], return_df=True)
# Out:
#         lb_stat  lb_pvalue
# 10  1672.971009        0.0
# 20  2759.140037        0.0
# 30  3516.359258        0.0

# %% [markdown]
# ## LM test

# %%
# import function test LM-Arch
import statsmodels.api as sm
test_LM_ARCH=sm.stats.diagnostic.het_arch

# %%
# testing LM-ARCH
# pvalue < alpha -> ARCH
lm, lmpval, f, pval, result_int =test_LM_ARCH(bmw_returns['log_ret'].dropna(), nlags=20, store=True)
print ('Estadístico LM: ', lm)
print ('p-value: ', lmpval)
print ('Estadístico F: ', f)
print ('p-value: ', pval)
# Out:
# Estadístico LM:  774.9851559581772
# p-value:  2.8767223815171056e-151
# Estadístico F:  44.206165564336374
# p-value:  2.728978668316641e-162

# %%
#
result_int.resols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.124
# Method:                 Least Squares   F-statistic:                     44.21
# Date:                Wed, 24 Nov 2021   Prob (F-statistic):          2.73e-162
# Time:                        20:17:21   Log-Likelihood:                 32839.
# No. Observations:                6129   AIC:                        -6.564e+04
# Df Residuals:                    6108   BIC:                        -6.550e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001   1.93e-05      6.648      0.000    9.06e-05       0.000
# x1             0.0335      0.013      2.621      0.009       0.008       0.059
# x2             0.1407      0.013     10.988      0.000       0.116       0.166
# x3             0.0655      0.013      5.061      0.000       0.040       0.091
# x4             0.0556      0.013      4.299      0.000       0.030       0.081
# x5             0.0320      0.013      2.472      0.013       0.007       0.057
# x6             0.0654      0.013      5.044      0.000       0.040       0.091
# x7             0.0277      0.013      2.135      0.033       0.002       0.053
# x8             0.0552      0.013      4.259      0.000       0.030       0.081
# x9             0.0097      0.013      0.751      0.453      -0.016       0.035
# x10            0.0123      0.013      0.946      0.344      -0.013       0.038
# x11            0.0444      0.013      3.422      0.001       0.019       0.070
# x12            0.0170      0.013      1.312      0.190      -0.008       0.042
# x13            0.0506      0.013      3.901      0.000       0.025       0.076
# x14            0.0640      0.013      4.934      0.000       0.039       0.089
# x15            0.0002      0.013      0.012      0.991      -0.025       0.026
# x16            0.0095      0.013      0.729      0.466      -0.016       0.035
# x17            0.0337      0.013      2.605      0.009       0.008       0.059
# x18            0.0209      0.013      1.618      0.106      -0.004       0.046
# x19           -0.0140      0.013     -1.092      0.275      -0.039       0.011
# x20            0.0057      0.013      0.444      0.657      -0.019       0.031
# ==============================================================================
# Omnibus:                     7970.904   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1798524.853
# Skew:                           7.205   Prob(JB):                         0.00
# Kurtosis:                      85.674   Cond. No.                         998.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # GARCH (1, 1)

# %%
from arch.univariate import ARX
from arch.univariate import ARCH, GARCH

# %%
# Modelo AR para la media
ar = ARX(100*bmw_returns['log_ret'].dropna(), lags=[15])
print(ar.fit().summary())
# Out:
#                      AR - Constant Variance Model Results
# ==============================================================================
# Dep. Variable:                log_ret   R-squared:                       0.000
# Mean Model:                        AR   Adj. R-squared:                  0.000
# Vol Model:          Constant Variance   Log-Likelihood:               -13484.1
# Distribution:                  Normal   AIC:                           26974.3
# Method:            Maximum Likelihood   BIC:                           26994.4
#                                         No. Observations:                 6134
# Date:                Wed, Nov 24 2021   Df Residuals:                     6132
# Time:                        20:17:22   Df Model:                            2
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# Const           0.0273  2.788e-02      0.978      0.328 [-2.737e-02,8.189e-02]
# log_ret[15]    -0.0184  1.689e-02     -1.089      0.276 [-5.150e-02,1.472e-02]
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# sigma2         4.7524      0.156     30.511 1.852e-204 [  4.447,  5.058]
# ========================================================================
#
# Covariance estimator: White's Heteroskedasticity Consistent Estimator

# %%
# MODELO 
# GARCH(1,1)
ar.volatility = GARCH(p=1,q=1)
res = ar.fit(update_freq=0, disp="off")
print(res.summary())
# Out:
#                            AR - GARCH Model Results
# ==============================================================================
# Dep. Variable:                log_ret   R-squared:                       0.000
# Mean Model:                        AR   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -12583.2
# Distribution:                  Normal   AIC:                           25176.4
# Method:            Maximum Likelihood   BIC:                           25210.0
#                                         No. Observations:                 6134
# Date:                Wed, Nov 24 2021   Df Residuals:                     6132
# Time:                        20:17:23   Df Model:                            2
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# Const           0.0541  2.126e-02      2.546  1.090e-02  [1.245e-02,9.578e-02]
# log_ret[15]    -0.0221  1.291e-02     -1.709  8.739e-02 [-4.738e-02,3.236e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0242  7.926e-03      3.052  2.273e-03 [8.656e-03,3.972e-02]
# alpha[1]       0.0590  8.439e-03      6.987  2.809e-12 [4.242e-02,7.550e-02]
# beta[1]        0.9372  8.747e-03    107.143      0.000     [  0.920,  0.954]
# ============================================================================
#
# Covariance estimator: robust

# %%
fig = res.plot(annualize="D")

# %%
# Análisis Residuos
mod1_std_resid=(res.resid / res.conditional_volatility).astype('float64').to_period('D').sort_index().dropna()

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:title={'center':'Autocorrelation'}>,
#         <AxesSubplot:title={'center':'Partial Autocorrelation'}>],
#        dtype=object))

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid**2)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:title={'center':'Autocorrelation'}>,
#         <AxesSubplot:title={'center':'Partial Autocorrelation'}>],
#        dtype=object))

# %%
#
# testing Ljung-Box
# pvalue < alpha -> No Ruido Blanco
test_Ljung_Box(mod1_std_resid**2, lags=[10,20,30], return_df=True)
# Out:
#       lb_stat  lb_pvalue
# 10   6.377469   0.782616
# 20  15.188523   0.765521
# 30  26.501211   0.649322

# %%
# qqplot
sm.qqplot(mod1_std_resid,line='45')
plt.show()
# Out:
# C:\Users\Alvaro\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %% [markdown]
#  ## GARCH(1,1) + t-student

# %%
#
from arch.univariate import StudentsT

# %%
#
ar.distribution = StudentsT()
res = ar.fit(update_freq=0, disp="off")
print(res.summary())
# Out:
#                               AR - GARCH Model Results
# ====================================================================================
# Dep. Variable:                      log_ret   R-squared:                       0.000
# Mean Model:                              AR   Adj. R-squared:                  0.000
# Vol Model:                            GARCH   Log-Likelihood:               -12434.3
# Distribution:      Standardized Student's t   AIC:                           24880.5
# Method:                  Maximum Likelihood   BIC:                           24920.9
#                                               No. Observations:                 6134
# Date:                      Wed, Nov 24 2021   Df Residuals:                     6132
# Time:                              20:17:29   Df Model:                            2
#                                   Mean Model
# ==============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
# ------------------------------------------------------------------------------
# Const           0.0372  1.948e-02      1.909  5.632e-02 [-1.001e-03,7.536e-02]
# log_ret[15]    -0.0175  1.184e-02     -1.482      0.138 [-4.075e-02,5.663e-03]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0177  5.919e-03      2.995  2.748e-03 [6.124e-03,2.932e-02]
# alpha[1]       0.0535  7.082e-03      7.549  4.388e-14 [3.958e-02,6.735e-02]
# beta[1]        0.9447  7.091e-03    133.228      0.000     [  0.931,  0.959]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             6.0929      0.455     13.394  6.585e-41 [  5.201,  6.985]
# ========================================================================
#
# Covariance estimator: robust

# %%
#
fig = res.plot(annualize="D")

# %%
# Análisis Residuos
mod1_std_resid=(res.resid / res.conditional_volatility).astype('float64').to_period('D').sort_index().dropna()

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:title={'center':'Autocorrelation'}>,
#         <AxesSubplot:title={'center':'Partial Autocorrelation'}>],
#        dtype=object))

# %%
# Plot Autocorrelation
plot_correlations(mod1_std_resid**2)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<AxesSubplot:>, <AxesSubplot:title={'center':'Autocorrelation'}>,
#         <AxesSubplot:title={'center':'Partial Autocorrelation'}>],
#        dtype=object))

# %%
#
# testing Ljung-Box
# pvalue < alpha -> No Ruido Blanco
test_Ljung_Box(mod1_std_resid**2, lags=[10,20,30], return_df=True)
# Out:
#       lb_stat  lb_pvalue
# 10  10.240595   0.419645
# 20  18.455381   0.557437
# 30  30.348775   0.447899

# %%
# qqplot t-student
sm.qqplot(mod1_std_resid,dist=stats.t,fit=True,line='45')
plt.show()
# Out:
# C:\Users\Alvaro\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %% [markdown]
# ## Forecast Volatility

# %%
# Predicción 30 días
forecasts = res.forecast(horizon=30, reindex=False)

# %%
# Mean
predictions_GARCH = forecasts.mean
predictions_GARCH
# Out:
#                 h.01      h.02      h.03      h.04      h.05      h.06  \
# Date
# 2020-10-30  0.026636  0.059968  0.041828  0.090268  0.010574  0.023337
#
#                 h.07      h.08     h.09      h.10  ...     h.21      h.22  \
# Date                                               ...
# 2020-10-30  0.024814  0.044314  0.03169  0.039374  ...  0.03677  0.036745
#
#                 h.23      h.24      h.25      h.26      h.27      h.28  \
# Date
# 2020-10-30  0.036402  0.036624  0.036489  0.036179  0.035668  0.034771
#
#                h.29      h.30
# Date
# 2020-10-30  0.03667  0.036712
#
# [1 rows x 30 columns]

# %%
# Varianza
(forecasts.variance**0.5)*np.sqrt(252)
# Out:
#                  h.01       h.02       h.03       h.04       h.05       h.06  \
# Date
# 2020-10-30  31.912807  31.952869  31.992806  32.032619  32.072307  32.111872
#
#                  h.07       h.08       h.09       h.10  ...       h.21  \
# Date                                                    ...
# 2020-10-30  32.151315  32.190635  32.229834  32.268912  ...  32.695806
#
#                  h.22       h.23       h.24       h.25       h.26       h.27  \
# Date
# 2020-10-30  32.733483  32.771047  32.808497  32.845834  32.883059  32.920172
#
#                  h.28       h.29       h.30
# Date
# 2020-10-30  32.957175  32.994066  33.030847
#
# [1 rows x 30 columns]

# %%
bmw_GARCH_prices = (np.exp(np.cumsum(predictions_GARCH))*price_bmw2)
bmw_GARCH_prices
# Out:
#                 h.01       h.02       h.03       h.04       h.05       h.06  \
# Date
# 2020-10-30  57.54119  59.491475  58.422016  61.321645  56.624324  57.351671
#
#                  h.07       h.08       h.09       h.10  ...       h.21  \
# Date                                                    ...
# 2020-10-30  57.436428  58.567424  57.832698  58.278816  ...  58.127285
#
#                  h.22       h.23       h.24       h.25       h.26       h.27  \
# Date
# 2020-10-30  58.125779  58.105897  58.118768  58.110934  58.092915  58.063263
#
#                  h.28      h.29       h.30
# Date
# 2020-10-30  58.011174  58.12147  58.123872
#
# [1 rows x 30 columns]

# %%
route= "C:/Users/Alvaro/Downloads/BMW.MI.csv"
bmw_nov_2020 = pd.read_csv(route)
bmw_nov_2020.drop(['Low','High','Open','Volume','Close'], axis=1)
# Out:
#           Date  Adj Close
# 0   2020-11-02  56.963745
# 1   2020-11-03  59.140701
# 2   2020-11-04  59.465336
# 3   2020-11-05  61.546814
# 4   2020-11-06  61.078957
# 5   2020-11-09  64.535355
# 6   2020-11-10  66.339943
# 7   2020-11-11  67.227913
# 8   2020-11-12  67.533447
# 9   2020-11-13  67.600288
# 10  2020-11-16  69.509903
# 11  2020-11-17  69.557632
# 12  2020-11-18  70.531540
# 13  2020-11-19  70.560181
# 14  2020-11-20  70.541092
# 15  2020-11-23  70.770248
# 16  2020-11-24  73.014038
# 17  2020-11-25  72.126068
# 18  2020-11-26  70.951653
# 19  2020-11-27  69.691307
